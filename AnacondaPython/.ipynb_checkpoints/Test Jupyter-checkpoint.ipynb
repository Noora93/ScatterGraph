# %% [markdown]
# # This is a Test graph
# ### "Community Health Obesity and Diabetes Related Indicators"
# ##### Data shown in the graph displays the number of different events occured between 2009 - 2011

# %%
import pandas as pd
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
dataset = pd.read_csv("C:\Users\Noora\Downloads\HealthData.csv")

# %matplotlib inline

dataset2 = dataset [['Indicator', 'Total Event Counts']]

ind_group = dataset2.groupby('Indicator')

totals = ind_group.sum()

my_plot = totals.plot(kind='bar')
