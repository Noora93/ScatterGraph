# %%
import pandas as pd
import matplotlib
import numpy as np
import matplotlib.pyplot as plt

plt.style.use('seaborn-colorblind')

dataset = pd.read_csv("C:\Users\Noora\Downloads\PDI.csv")
print(dataset)
# Out:
#       Year Patient County PDI Number                                  PDI  \
# 0     2009      STATEWIDE     PDI_14                               Asthma
# 1     2010      STATEWIDE     PDI_14                               Asthma
# 2     2011      STATEWIDE     PDI_14                               Asthma
# 3     2012      STATEWIDE     PDI_14                               Asthma
# 4     2009      STATEWIDE     PDI_15    Diabetes Short-term Complications
# 5     2010      STATEWIDE     PDI_15    Diabetes Short-term Complications
# 6     2011      STATEWIDE     PDI_15    Diabetes Short-term Complications
# 7     2012      STATEWIDE     PDI_15    Diabetes Short-term Complications
# 8     2009      STATEWIDE     PDI_16                      Gastroenteritis
# 9     2010      STATEWIDE     PDI_16                      Gastroenteritis
# 10    2011      STATEWIDE     PDI_16                      Gastroenteritis
# 11    2012      STATEWIDE     PDI_16                      Gastroenteritis
# ...

# %%
dataset2 = dataset [['Year', 'PDI', 'Observed']]
dataset2
# Out:
#       Year                                  PDI  Observed
# 0     2009                               Asthma    242.83
# 1     2010                               Asthma    205.77
# 2     2011                               Asthma    206.28
# 3     2012                               Asthma    210.39
# 4     2009    Diabetes Short-term Complications     27.72
# 5     2010    Diabetes Short-term Complications     24.73
# 6     2011    Diabetes Short-term Complications     24.95
# 7     2012    Diabetes Short-term Complications     23.74
# 8     2009                      Gastroenteritis    130.33
# 9     2010                      Gastroenteritis    102.54
# 10    2011                      Gastroenteritis     99.77
# 11    2012                      Gastroenteritis     87.89
# 12    2009              Urinary Tract Infection     43.75
# 13    2010              Urinary Tract Infection     42.09
# 14    2011              Urinary Tract Infection     39.55
# ...

# %%
dataset2.plot();

# %%
dataset2.plot('PDI', 'Observed', kind = 'scatter')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-11-ac98b7260cc8> in <module>()
# ----> 1 dataset2.plot('PDI', 'Observed', kind = 'scatter')
#
# C:\Users\Noora\Anaconda2\lib\site-packages\pandas\tools\plotting.pyc in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    3772                           fontsize=fontsize, colormap=colormap, table=table,
#    3773                           yerr=yerr, xerr=xerr, secondary_y=secondary_y,
# -> 3774                           sort_columns=sort_columns, **kwds)
#    3775     __call__.__doc__ = plot_frame.__doc__
#    3776
#
# ...
